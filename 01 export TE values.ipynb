# %%
import os
from main import DorsognaTE, RandomWalkTE, CorrRandomWalkTE, DorsognaNoMorseTE, DorsognaNoisyTE

# %% [markdown]
# # D'Orsogna phenotypes

# %%
phenotype_dict = {
    'singlemill':[0.5,0.1],
    'doublemill':[0.9,0.5],
    'doublering':[0.5,0.5],
    'collswarm':[0.5,0.9],
    'escapesymm':[2,0.9],
    'escapeunsymm':[2,2],
    'escapecoll':[2,3]
    }

phenotype_fr_lengths = {
    'singlemill':[0.0625,0.125],
    'doublemill':[0.125,0.25],
    'doublering':[0.625,0.125],
    'collswarm':[0.03,0.05],
    'escapesymm':[20,40],
    'escapeunsymm':[20,40],
    'escapecoll':[20,40]
}

# %%
output_dir = 'simulations_dorsogna'

for phenotype_name, values in phenotype_dict.items():
    C, l = values
    os.makedirs(output_dir, exist_ok=True)
    insights_path = os.path.join(output_dir, phenotype_name)
    model = DorsognaTE(outdir=insights_path)
    model.develop_model(
            C=C,
            l=l,
            phenotype_name=phenotype_name,
            particle_count=100,
            t_max=40,
            vel_scale=0.1,
            fps=20,
            dt=0.1
        )

    # Calculate all-pairs scheme
    for TE_ver in ['linvel','angvel']:
        model.compute_modelTE(TE_ver = TE_ver,
                      TE_embedding = 15,
                      save_graph = False)

    # Calculate fixed-radius scheme
    for TE_ver in ['linvel','angvel']:
        for fr_length in phenotype_fr_lengths[phenotype_name]:
            model.compute_modelTE(TE_ver = TE_ver,
                        TE_embedding = 15,
                        neighbor_radius = fr_length,
                        save_graph = False)

    # Calculate nearest-neighbors scheme
    for TE_ver in ['linvel','angvel']:
        for nn_count in [10,30]:
            model.compute_modelTE(TE_ver = TE_ver,
                        TE_embedding = 15,
                        nearest_neighbors = nn_count,
                        save_graph = False)
    
    print("\n")
# Out:
# Saved simulation to simulations_dorsogna/singlemill/sim_singlemill_0.5_0.1.gif
# Saved simulation to simulations_dorsogna/doublemill/sim_doublemill_0.9_0.5.gif
# Saved simulation to simulations_dorsogna/doublering/sim_doublering_0.5_0.5.gif
# Saved simulation to simulations_dorsogna/collswarm/sim_collswarm_0.5_0.9.gif
# Saved simulation to simulations_dorsogna/escapesymm/sim_escapesymm_2_0.9.gif
# Saved simulation to simulations_dorsogna/escapeunsymm/sim_escapeunsymm_2_2.gif
# Saved simulation to simulations_dorsogna/escapecoll/sim_escapecoll_2_3.gif

# %% [markdown]
# # Null models

# %%
folder = 'simulations_null_models'
os.makedirs(folder, exist_ok=True)

# %%
# Random walk
insights_path = os.path.join(folder, 'randomwalk')
rw_model = RandomWalkTE(outdir=insights_path)

rw_model.develop_model(
        particle_count=100,
        sigma=1.0,
        t_max=40,
        vel_scale=0.1,
        seed = 42,
        fps=10,
        dt=0.1,
        animate=True
    )
# Out:
# Saved simulation to simulations_null_models/randomwalk/sim_randomwalk_s1.0_seed42.gif

# %%
# Correlated random walk
insights_path = os.path.join(folder, 'corrrandomwalk')
os.makedirs(insights_path, exist_ok=True)
corr_rw_model = CorrRandomWalkTE(outdir=insights_path)

for kappa in [1,4,8]:
    corr_rw_model.develop_model(
        particle_count= 2,
        kappa = kappa,
        t_max=40,
        seed = 0,
        vel_scale=0.1,
        fps=10,
        dt=0.1,
        animate=True
    )
# Out:
# Saved simulation to simulations_null_models/corrrandomwalk/sim_corrrandomwalk_kappa1_seed0.gif
# Saved simulation to simulations_null_models/corrrandomwalk/sim_corrrandomwalk_kappa4_seed0.gif
# Saved simulation to simulations_null_models/corrrandomwalk/sim_corrrandomwalk_kappa8_seed0.gif

# %%
# D'orsogna no morse
insights_path = os.path.join(folder, 'dorsognanomorse')
os.makedirs(insights_path, exist_ok=True)
do_no_morse_model = DorsognaNoMorseTE(outdir=insights_path)

do_no_morse_model.develop_model(
    phenotype_name="dorsognanomorse",
    particle_count=100,
    t_max=40,
    vel_scale=0.1,
    seed = 0,
    fps=10,
    dt=0.1,
    animate=True
)
# Out:
# Saved simulation to simulations_null_models/dorsognanomorse/sim_dorsognanomorse_seed0.gif

# %%
# D'orsogna noisy
insights_path = os.path.join(folder, 'dorsognanoisy')
os.makedirs(insights_path, exist_ok=True)
do_noise_model = DorsognaNoisyTE(outdir=insights_path)

for diff_coef in [0.1,2]:
    do_noise_model.develop_model(
            particle_count=100,
            phenotype_name= "dorsognanoisy",
            t_max=40,
            vel_scale=0.1,
            seed = 0,
            diff_coef = diff_coef, 
            fps=10,
            dt=0.1,
            animate=True
        )
# Out:
# Saved simulation to simulations_null_models/dorsognanoisy/sim_dorsognanoisy_diff0.1_seed0.gif
# Saved simulation to simulations_null_models/dorsognanoisy/sim_dorsognanoisy_diff2_seed0.gif
