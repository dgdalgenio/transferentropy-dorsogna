# %% [markdown]
# # Check if required packages are complete

# %%
import importlib
import subprocess

packages = {
    ## packages for exporting of values ##
    "numpy": "numpy",
    "matplotlib": "matplotlib",
    "scipy": "scipy",
    "pandas": "pandas",
    "sklearn": "scikit-learn",
    "tqdm": "tqdm",
    "pyinform": "pyinform",
    "jpype1": "jpype1",
    ## packages for analysis ##
    "dcor": "dcor",
    "statsmodels": "statsmodels"
}

for import_name, install_name in packages.items():
    if importlib.util.find_spec(import_name) is None:
        print(f"Installing {install_name}...")
        subprocess.run(["pip", "install", install_name], check=True)
    else:
        print(f"{install_name} already installed.")

# %% [markdown]
# # Clone JIDT

# %%
# !git clone https://github.com/jlizier/jidt temp_jidt
# !cp -r temp_jidt/. jidt/
# !rm -rf temp_jidt
# Out:
# Cloning into 'temp_jidt'...
# remote: Enumerating objects: 9761, done.
# remote: Counting objects: 100% (346/346), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 9761 (delta 284), reused 235 (delta 208), pack-reused 9415 (from 2)
# Receiving objects: 100% (9761/9761), 53.90 MiB | 8.76 MiB/s, done.
# Resolving deltas: 100% (5304/5304), done.

# %% [markdown]
# ## Configure Java location

# %%
import os
os.environ["JAVA_HOME"] = r"C:\Program Files\Eclipse Adoptium\jdk-25.0.2.10-hotspot"
os.environ["PATH"] = os.environ["JAVA_HOME"] + r"\bin;" + os.environ["PATH"]

# Verify
import subprocess
subprocess.run(["java", "-version"])
